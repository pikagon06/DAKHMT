# %% [markdown]
# # <div style="text-align: center; background-color: #1E90FF; padding: 20px; border-radius: 10px; color: white; font-family: Times New Roman, sans-serif;">ĐỒ ÁN CHUYÊN NGÀNH KHOA HỌC MÁY TÍNH</div>
# # <p style="padding:10px;background-color:#0f4c5c;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">PHÂN TÍCH VÀ DỰ ĐOÁN BỆNH NHÂN MẮC BỆNH UNG THƯ PHỔI</p>
#
# <p style="text-align:center; ">
# <img src="https://st.depositphotos.com/1909187/4810/i/450/depositphotos_48100511-stock-photo-lung-cancer-tumor-detail.jpg" style='width: 300px; height: 300px;'>
# </p>
#
#
# ### <div style="text-align: center; font-size: 20px; color: #333; font-family: Times New Roman, sans-serif;">THÔNG TIN SINH VIÊN</div>
#
# - **Họ và tên**: <span style="color: #2E8B57; font-weight: bold;">Lê Doãn Anh</span>
# - **Mã sinh viên**: <span style="color: #2E8B57; font-weight: bold;">2121050186</span>
# - **Lớp**: <span style="color: #2E8B57; font-weight: bold;">DCCTCT66_07E</span>
# - **Giảng viên hướng dẫn**: <span style="color: #2E8B57; font-weight: bold;">ThS. Nguyễn Thị Phương Bắc</span>
#
# ---

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Import các thư viện cần thiết</p>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <a id="2"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Khái quát về tập dữ liệu</p>

# %% [markdown]
# # Mô Tả Tập Dữ Liệu
#
# - **GENDER:**
#   - M [Male]
#   - F [Female]
#
# - **AGE:**
#   - Tuổi của bệnh nhân.
#
# - **SMOKING:**
#   - 2 [Yes] - Bệnh nhân có hút thuốc.
#   - 1 [No] - Bệnh nhân không hút thuốc.
#
# - **YELLOW_FINGERS:**
#   - 2 [Yes] - Bệnh nhân có dấu hiệu ngón tay vàng.
#   - 1 [No] - Bệnh nhân không có dấu hiệu ngón tay vàng.
#
# - **ANXIETY:**
#   - 2 [Yes] - Bệnh nhân có lo âu.
#   - 1 [No] - Bệnh nhân không có lo âu.
#
# - **PEER_PRESSURE:**
#   - 2 [Yes] - Bệnh nhân cảm thấy áp lực từ bạn bè.
#   - 1 [No] - Bệnh nhân không cảm thấy áp lực từ bạn bè.
#
# - **CHRONIC DISEASE:**
#   - 2 [Yes] - Bệnh nhân có bệnh lý mãn tính.
#   - 1 [No] - Bệnh nhân không có bệnh lý mãn tính.
#
# - **FATIGUE:**
#   - 2 [Yes] - Bệnh nhân cảm thấy mệt mỏi.
#   - 1 [No] - Bệnh nhân không cảm thấy mệt mỏi.
#
# - **ALLERGY:**
#   - 2 [Yes] - Bệnh nhân bị dị ứng.
#   - 1 [No] - Bệnh nhân không bị dị ứng.
#
# - **WHEEZING:**
#   - 2 [Yes] - Bệnh nhân có thở khò khè.
#   - 1 [No] - Bệnh nhân không có thở khò khè.
#
# - **ALCOHOL CONSUMING:**
#   - 2 [Yes] - Bệnh nhân có sử dụng rượu.
#   - 1 [No] - Bệnh nhân không sử dụng rượu.
#
# - **COUGHING:**
#   - 2 [Yes] - Bệnh nhân có ho.
#   - 1 [No] - Bệnh nhân không có ho.
#
# - **SHORTNESS OF BREATH:**
#   - 2 [Yes] - Bệnh nhân cảm thấy khó thở.
#   - 1 [No] - Bệnh nhân không cảm thấy khó thở.
#
# - **SWALLOWING DIFFICULTY:**
#   - 2 [Yes] - Bệnh nhân gặp khó khăn khi nuốt.
#   - 1 [No] - Bệnh nhân không gặp khó khăn khi nuốt.
#
# - **CHEST PAIN:**
#   - 2 [Yes] - Bệnh nhân có đau ngực.
#   - 1 [No] - Bệnh nhân không có đau ngực.
#
# - **LUNG_CANCER:**
#   - YES [Positive] - Bệnh nhân mắc bệnh ung thư phổi.
#   - NO [Negative] - Bệnh nhân không mắc bệnh ung thư phổi.

# %%
data = pd.read_csv("Data/survey lung cancer.csv")

# %% [markdown]
# <a id="3"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Đọc tâp dữ liệu</p>
# <br>
#
# **Đọc tập dữ liệu để hiểu về các thuộc tính của tập dữ liệu.**

# %%
print(f"Kích cỡ của tập dữ liệu : {data.shape}")
print(f"\nMô tả thuộc tính của tập dữ liệu :")
data.head().style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# Kích cỡ của tập dữ liệu : (309, 16)
#
# Mô tả thuộc tính của tập dữ liệu :
# <style type="text/css">
# #T_1e2a2_row0_col0, #T_1e2a2_row0_col1, #T_1e2a2_row0_col2, #T_1e2a2_row0_col3, #T_1e2a2_row0_col4, #T_1e2a2_row0_col5, #T_1e2a2_row0_col6, #T_1e2a2_row0_col7, #T_1e2a2_row0_col8, #T_1e2a2_row0_col9, #T_1e2a2_row0_col10, #T_1e2a2_row0_col11, #T_1e2a2_row0_col12, #T_1e2a2_row0_col13, #T_1e2a2_row0_col14, #T_1e2a2_row0_col15, #T_1e2a2_row1_col0, #T_1e2a2_row1_col1, #T_1e2a2_row1_col2, #T_1e2a2_row1_col3, #T_1e2a2_row1_col4, #T_1e2a2_row1_col5, #T_1e2a2_row1_col6, #T_1e2a2_row1_col7, #T_1e2a2_row1_col8, #T_1e2a2_row1_col9, #T_1e2a2_row1_col10, #T_1e2a2_row1_col11, #T_1e2a2_row1_col12, #T_1e2a2_row1_col13, #T_1e2a2_row1_col14, #T_1e2a2_row1_col15, #T_1e2a2_row2_col0, #T_1e2a2_row2_col1, #T_1e2a2_row2_col2, #T_1e2a2_row2_col3, #T_1e2a2_row2_col4, #T_1e2a2_row2_col5, #T_1e2a2_row2_col6, #T_1e2a2_row2_col7, #T_1e2a2_row2_col8, #T_1e2a2_row2_col9, #T_1e2a2_row2_col10, #T_1e2a2_row2_col11, #T_1e2a2_row2_col12, #T_1e2a2_row2_col13, #T_1e2a2_row2_col14, #T_1e2a2_row2_col15, #T_1e2a2_row3_col0, #T_1e2a2_row3_col1, #T_1e2a2_row3_col2, #T_1e2a2_row3_col3, #T_1e2a2_row3_col4, #T_1e2a2_row3_col5, #T_1e2a2_row3_col6, #T_1e2a2_row3_col7, #T_1e2a2_row3_col8, #T_1e2a2_row3_col9, #T_1e2a2_row3_col10, #T_1e2a2_row3_col11, #T_1e2a2_row3_col12, #T_1e2a2_row3_col13, #T_1e2a2_row3_col14, #T_1e2a2_row3_col15, #T_1e2a2_row4_col0, #T_1e2a2_row4_col1, #T_1e2a2_row4_col2, #T_1e2a2_row4_col3, #T_1e2a2_row4_col4, #T_1e2a2_row4_col5, #T_1e2a2_row4_col6, #T_1e2a2_row4_col7, #T_1e2a2_row4_col8, #T_1e2a2_row4_col9, #T_1e2a2_row4_col10, #T_1e2a2_row4_col11, #T_1e2a2_row4_col12, #T_1e2a2_row4_col13, #T_1e2a2_row4_col14, #T_1e2a2_row4_col15 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_1e2a2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e2a2_level0_col0" class="col_heading level0 col0" >GENDER</th>
#       <th id="T_1e2a2_level0_col1" class="col_heading level0 col1" >AGE</th>
#       <th id="T_1e2a2_level0_col2" class="col_heading level0 col2" >SMOKING</th>
#       <th id="T_1e2a2_level0_col3" class="col_heading level0 col3" >YELLOW_FINGERS</th>
#       <th id="T_1e2a2_level0_col4" class="col_heading level0 col4" >ANXIETY</th>
#       <th id="T_1e2a2_level0_col5" class="col_heading level0 col5" >PEER_PRESSURE</th>
#       <th id="T_1e2a2_level0_col6" class="col_heading level0 col6" >CHRONIC DISEASE</th>
#       <th id="T_1e2a2_level0_col7" class="col_heading level0 col7" >FATIGUE </th>
#       <th id="T_1e2a2_level0_col8" class="col_heading level0 col8" >ALLERGY </th>
#       <th id="T_1e2a2_level0_col9" class="col_heading level0 col9" >WHEEZING</th>
#       <th id="T_1e2a2_level0_col10" class="col_heading level0 col10" >ALCOHOL CONSUMING</th>
#       <th id="T_1e2a2_level0_col11" class="col_heading level0 col11" >COUGHING</th>
#       <th id="T_1e2a2_level0_col12" class="col_heading level0 col12" >SHORTNESS OF BREATH</th>
#       <th id="T_1e2a2_level0_col13" class="col_heading level0 col13" >SWALLOWING DIFFICULTY</th>
#       <th id="T_1e2a2_level0_col14" class="col_heading level0 col14" >CHEST PAIN</th>
#       <th id="T_1e2a2_level0_col15" class="col_heading level0 col15" >LUNG_CANCER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e2a2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1e2a2_row0_col0" class="data row0 col0" >M</td>
#       <td id="T_1e2a2_row0_col1" class="data row0 col1" >69</td>
#       <td id="T_1e2a2_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_1e2a2_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_1e2a2_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_1e2a2_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_1e2a2_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_1e2a2_row0_col7" class="data row0 col7" >2</td>
#       <td id="T_1e2a2_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_1e2a2_row0_col9" class="data row0 col9" >2</td>
#       <td id="T_1e2a2_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_1e2a2_row0_col11" class="data row0 col11" >2</td>
#       <td id="T_1e2a2_row0_col12" class="data row0 col12" >2</td>
#       <td id="T_1e2a2_row0_col13" class="data row0 col13" >2</td>
#       <td id="T_1e2a2_row0_col14" class="data row0 col14" >2</td>
#       <td id="T_1e2a2_row0_col15" class="data row0 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_1e2a2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1e2a2_row1_col0" class="data row1 col0" >M</td>
#       <td id="T_1e2a2_row1_col1" class="data row1 col1" >74</td>
#       <td id="T_1e2a2_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_1e2a2_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_1e2a2_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_1e2a2_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_1e2a2_row1_col6" class="data row1 col6" >2</td>
#       <td id="T_1e2a2_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_1e2a2_row1_col8" class="data row1 col8" >2</td>
#       <td id="T_1e2a2_row1_col9" class="data row1 col9" >1</td>
#       <td id="T_1e2a2_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_1e2a2_row1_col11" class="data row1 col11" >1</td>
#       <td id="T_1e2a2_row1_col12" class="data row1 col12" >2</td>
#       <td id="T_1e2a2_row1_col13" class="data row1 col13" >2</td>
#       <td id="T_1e2a2_row1_col14" class="data row1 col14" >2</td>
#       <td id="T_1e2a2_row1_col15" class="data row1 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_1e2a2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1e2a2_row2_col0" class="data row2 col0" >F</td>
#       <td id="T_1e2a2_row2_col1" class="data row2 col1" >59</td>
#       <td id="T_1e2a2_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_1e2a2_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_1e2a2_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_1e2a2_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_1e2a2_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_1e2a2_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_1e2a2_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_1e2a2_row2_col9" class="data row2 col9" >2</td>
#       <td id="T_1e2a2_row2_col10" class="data row2 col10" >1</td>
#       <td id="T_1e2a2_row2_col11" class="data row2 col11" >2</td>
#       <td id="T_1e2a2_row2_col12" class="data row2 col12" >2</td>
#       <td id="T_1e2a2_row2_col13" class="data row2 col13" >1</td>
#       <td id="T_1e2a2_row2_col14" class="data row2 col14" >2</td>
#       <td id="T_1e2a2_row2_col15" class="data row2 col15" >NO</td>
#     </tr>
#     <tr>
#       <th id="T_1e2a2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1e2a2_row3_col0" class="data row3 col0" >M</td>
#       <td id="T_1e2a2_row3_col1" class="data row3 col1" >63</td>
#       <td id="T_1e2a2_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_1e2a2_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_1e2a2_row3_col4" class="data row3 col4" >2</td>
#       <td id="T_1e2a2_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_1e2a2_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_1e2a2_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_1e2a2_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_1e2a2_row3_col9" class="data row3 col9" >1</td>
#       <td id="T_1e2a2_row3_col10" class="data row3 col10" >2</td>
#       <td id="T_1e2a2_row3_col11" class="data row3 col11" >1</td>
#       <td id="T_1e2a2_row3_col12" class="data row3 col12" >1</td>
#       <td id="T_1e2a2_row3_col13" class="data row3 col13" >2</td>
#       <td id="T_1e2a2_row3_col14" class="data row3 col14" >2</td>
#       <td id="T_1e2a2_row3_col15" class="data row3 col15" >NO</td>
#     </tr>
#     <tr>
#       <th id="T_1e2a2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1e2a2_row4_col0" class="data row4 col0" >F</td>
#       <td id="T_1e2a2_row4_col1" class="data row4 col1" >63</td>
#       <td id="T_1e2a2_row4_col

# %%
print(f"Thông tin về các thuôc tính của tập dữ liệu :\n")
print(data.info())
# Out:
# Thông tin về các thuôc tính của tập dữ liệu :
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
#  15  LUNG_CANCER            309 non-null    object
# dtypes: int64(14), object(2)
# memory usage: 38.8+ KB
# None

# %% [markdown]
# <a id="4"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Khái quát tập dữ liệu</p>

# %%
print(f"Khái quát tập dữ liệu :")
data.describe().T.style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# Khái quát tập dữ liệu :
# <style type="text/css">
# #T_25cc5_row0_col0, #T_25cc5_row0_col1, #T_25cc5_row0_col2, #T_25cc5_row0_col3, #T_25cc5_row0_col4, #T_25cc5_row0_col5, #T_25cc5_row0_col6, #T_25cc5_row0_col7, #T_25cc5_row1_col0, #T_25cc5_row1_col1, #T_25cc5_row1_col2, #T_25cc5_row1_col3, #T_25cc5_row1_col4, #T_25cc5_row1_col5, #T_25cc5_row1_col6, #T_25cc5_row1_col7, #T_25cc5_row2_col0, #T_25cc5_row2_col1, #T_25cc5_row2_col2, #T_25cc5_row2_col3, #T_25cc5_row2_col4, #T_25cc5_row2_col5, #T_25cc5_row2_col6, #T_25cc5_row2_col7, #T_25cc5_row3_col0, #T_25cc5_row3_col1, #T_25cc5_row3_col2, #T_25cc5_row3_col3, #T_25cc5_row3_col4, #T_25cc5_row3_col5, #T_25cc5_row3_col6, #T_25cc5_row3_col7, #T_25cc5_row4_col0, #T_25cc5_row4_col1, #T_25cc5_row4_col2, #T_25cc5_row4_col3, #T_25cc5_row4_col4, #T_25cc5_row4_col5, #T_25cc5_row4_col6, #T_25cc5_row4_col7, #T_25cc5_row5_col0, #T_25cc5_row5_col1, #T_25cc5_row5_col2, #T_25cc5_row5_col3, #T_25cc5_row5_col4, #T_25cc5_row5_col5, #T_25cc5_row5_col6, #T_25cc5_row5_col7, #T_25cc5_row6_col0, #T_25cc5_row6_col1, #T_25cc5_row6_col2, #T_25cc5_row6_col3, #T_25cc5_row6_col4, #T_25cc5_row6_col5, #T_25cc5_row6_col6, #T_25cc5_row6_col7, #T_25cc5_row7_col0, #T_25cc5_row7_col1, #T_25cc5_row7_col2, #T_25cc5_row7_col3, #T_25cc5_row7_col4, #T_25cc5_row7_col5, #T_25cc5_row7_col6, #T_25cc5_row7_col7, #T_25cc5_row8_col0, #T_25cc5_row8_col1, #T_25cc5_row8_col2, #T_25cc5_row8_col3, #T_25cc5_row8_col4, #T_25cc5_row8_col5, #T_25cc5_row8_col6, #T_25cc5_row8_col7, #T_25cc5_row9_col0, #T_25cc5_row9_col1, #T_25cc5_row9_col2, #T_25cc5_row9_col3, #T_25cc5_row9_col4, #T_25cc5_row9_col5, #T_25cc5_row9_col6, #T_25cc5_row9_col7, #T_25cc5_row10_col0, #T_25cc5_row10_col1, #T_25cc5_row10_col2, #T_25cc5_row10_col3, #T_25cc5_row10_col4, #T_25cc5_row10_col5, #T_25cc5_row10_col6, #T_25cc5_row10_col7, #T_25cc5_row11_col0, #T_25cc5_row11_col1, #T_25cc5_row11_col2, #T_25cc5_row11_col3, #T_25cc5_row11_col4, #T_25cc5_row11_col5, #T_25cc5_row11_col6, #T_25cc5_row11_col7, #T_25cc5_row12_col0, #T_25cc5_row12_col1, #T_25cc5_row12_col2, #T_25cc5_row12_col3, #T_25cc5_row12_col4, #T_25cc5_row12_col5, #T_25cc5_row12_col6, #T_25cc5_row12_col7, #T_25cc5_row13_col0, #T_25cc5_row13_col1, #T_25cc5_row13_col2, #T_25cc5_row13_col3, #T_25cc5_row13_col4, #T_25cc5_row13_col5, #T_25cc5_row13_col6, #T_25cc5_row13_col7 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_25cc5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25cc5_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_25cc5_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_25cc5_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_25cc5_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_25cc5_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_25cc5_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_25cc5_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_25cc5_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25cc5_level0_row0" class="row_heading level0 row0" >AGE</th>
#       <td id="T_25cc5_row0_col0" class="data row0 col0" >309.000000</td>
#       <td id="T_25cc5_row0_col1" class="data row0 col1" >62.673139</td>
#       <td id="T_25cc5_row0_col2" class="data row0 col2" >8.210301</td>
#       <td id="T_25cc5_row0_col3" class="data row0 col3" >21.000000</td>
#       <td id="T_25cc5_row0_col4" class="data row0 col4" >57.000000</td>
#       <td id="T_25cc5_row0_col5" class="data row0 col5" >62.000000</td>
#       <td id="T_25cc5_row0_col6" class="data row0 col6" >69.000000</td>
#       <td id="T_25cc5_row0_col7" class="data row0 col7" >87.000000</td>
#     </tr>
#     <tr>
#       <th id="T_25cc5_level0_row1" class="row_heading level0 row1" >SMOKING</th>
#       <td id="T_25cc5_row1_col0" class="data row1 col0" >309.000000</td>
#       <td id="T_25cc5_row1_col1" class="data row1 col1" >1.563107</td>
#       <td id="T_25cc5_row1_col2" class="data row1 col2" >0.496806</td>
#       <td id="T_25cc5_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_25cc5_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_25cc5_row1_col5" class="data row1 col5" >2.000000</td>
#       <td id="T_25cc5_row1_col6" class="data row1 col6" >2.000000</td>
#       <td id="T_25cc5_row1_col7" class="data row1 col7" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_25cc5_level0_row2" class="row_heading level0 row2" >YELLOW_FINGERS</th>
#       <td id="T_25cc5_row2_col0" class="data row2 col0" >309.000000</td>
#       <td id="T_25cc5_row2_col1" class="data row2 col1" >1.569579</td>
#       <td id="T_25cc5_row2_col2" class="data row2 col2" >0.495938</td>
#       <td id="T_25cc5_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_25cc5_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_25cc5_row2_col5" class="data row2 col5" >2.000000</td>
#       <td id="T_25cc5_row2_col6" class="data row2 col6" >2.000000</td>
#       <td id="T_25cc5_row2_col7" class="data row2 col7" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_25cc5_level0_row3" class="row_heading level0 row3" >ANXIETY</th>
#       <td id="T_25cc5_row3_col0" class="data row3 col0" >309.000000</td>
#       <td id="T_25cc5_row3_col1" class="data row3 col1" >1.498382</td>
#       <td id="T_25cc5_row3_col2" class="data row3 col2" >0.500808</td>
#       <td id="T_25cc5_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_25cc5_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_25cc5_row3_col5" class="data row3 col5" >1.000000</td>
#       <td id="T_25cc5_row3_col6" class="data row3 col6" >2.000000</td>
#       <td id="T_25cc5_row3_col7" class="data row3 col7" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_25cc5_level0_row4" class="row_heading level0 row4" >PEER_PRESSURE</th>
#       <td id="T_25cc5_row4_col0" class="data row4 col0" >309.000000</td>
#       <td id="T_25cc5_row4_col1" class="data row4 col1" >1.501618</td>
#       <td id="T_25cc5_row4_col2" class="data row4 col2" >0.500808</td>
#       <td id="T_25cc5_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_25cc5_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_25cc5_row4_col5" class="data row4 col5" >2.000000</td>
#       <td id="T_25cc5_row4_col6" class="data row4 col6" >2.000000</td>
#       <td id="T_25cc5_row4_col7" class="data row4 col7" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_25cc5_level0_row5" class="row_heading level0 row5" >CHRONIC DISEASE</th>
#       <td id="T_25cc5_row5_col0" class="data row5 col0" >309.000000</td>
#       <td id="T_25cc5_row5_col1" class="data row5 col1" >1.504854</td>
#       <td id="T_25cc5_row5_col2" class="data row5 col2" >0.500787</td>
#       <td id="T_25cc5_row5_col3" class="data row5 col3" >1.000000</td>
#       <td id="T_25cc5_row5_col4" class="data row5 col4" >1.000000</td>
#       <td id="T_25cc5_row5_col5" class="data row5 col5" >2.000000</td>
#       <td id="T_25cc5_row5_col6" class="data row5 col6" >2.000000</td>
#       <td id="T_25cc5_row5_col7" class="data row5 col7" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_25cc5_level0_row6" class="row_heading level0 row6" >FATIGUE </th>
#       <td id="T_25cc5_row6_col0" class="data row6 col0" >309.000000</td>
#       <td id="T_25cc5_row6_col1" class="data row6 col1" >1.673139</td>
#       <td id="T_25cc5_row6_col2" class="data row6 col2" >0.469827</td>
#       <td id="T_25cc5_row6_col3" class="data row6 col3" >1.000000</td>
#       <td id="T_25cc5_row6_col4" class="data row6 col4" >1.000000</td>
#       <td id="T_25cc5_row6_col5" class="data row6 col5" >2.000000</td>
#       <td id="T_25cc5_row6_col6" class="data row6 col6" >2.000000</td>
#       <td id="T_25cc5_row6_col7" class="data row6 col7" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_25cc5_level0_row7" class="row_heading level0 row7" >ALLERGY </th>
#       <td id="T_25cc5_row7_col0" class="data row7 col0" >309.000000</td>

# %%
data.describe(include=object).T.style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_6530d_row0_col0, #T_6530d_row0_col1, #T_6530d_row0_col2, #T_6530d_row0_col3, #T_6530d_row1_col0, #T_6530d_row1_col1, #T_6530d_row1_col2, #T_6530d_row1_col3 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_6530d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6530d_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_6530d_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_6530d_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_6530d_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6530d_level0_row0" class="row_heading level0 row0" >GENDER</th>
#       <td id="T_6530d_row0_col0" class="data row0 col0" >309</td>
#       <td id="T_6530d_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_6530d_row0_col2" class="data row0 col2" >M</td>
#       <td id="T_6530d_row0_col3" class="data row0 col3" >162</td>
#     </tr>
#     <tr>
#       <th id="T_6530d_level0_row1" class="row_heading level0 row1" >LUNG_CANCER</th>
#       <td id="T_6530d_row1_col0" class="data row1 col0" >309</td>
#       <td id="T_6530d_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_6530d_row1_col2" class="data row1 col2" >YES</td>
#       <td id="T_6530d_row1_col3" class="data row1 col3" >270</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.isna().sum().to_frame().T.style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_6db0a_row0_col0, #T_6db0a_row0_col1, #T_6db0a_row0_col2, #T_6db0a_row0_col3, #T_6db0a_row0_col4, #T_6db0a_row0_col5, #T_6db0a_row0_col6, #T_6db0a_row0_col7, #T_6db0a_row0_col8, #T_6db0a_row0_col9, #T_6db0a_row0_col10, #T_6db0a_row0_col11, #T_6db0a_row0_col12, #T_6db0a_row0_col13, #T_6db0a_row0_col14, #T_6db0a_row0_col15 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_6db0a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6db0a_level0_col0" class="col_heading level0 col0" >GENDER</th>
#       <th id="T_6db0a_level0_col1" class="col_heading level0 col1" >AGE</th>
#       <th id="T_6db0a_level0_col2" class="col_heading level0 col2" >SMOKING</th>
#       <th id="T_6db0a_level0_col3" class="col_heading level0 col3" >YELLOW_FINGERS</th>
#       <th id="T_6db0a_level0_col4" class="col_heading level0 col4" >ANXIETY</th>
#       <th id="T_6db0a_level0_col5" class="col_heading level0 col5" >PEER_PRESSURE</th>
#       <th id="T_6db0a_level0_col6" class="col_heading level0 col6" >CHRONIC DISEASE</th>
#       <th id="T_6db0a_level0_col7" class="col_heading level0 col7" >FATIGUE </th>
#       <th id="T_6db0a_level0_col8" class="col_heading level0 col8" >ALLERGY </th>
#       <th id="T_6db0a_level0_col9" class="col_heading level0 col9" >WHEEZING</th>
#       <th id="T_6db0a_level0_col10" class="col_heading level0 col10" >ALCOHOL CONSUMING</th>
#       <th id="T_6db0a_level0_col11" class="col_heading level0 col11" >COUGHING</th>
#       <th id="T_6db0a_level0_col12" class="col_heading level0 col12" >SHORTNESS OF BREATH</th>
#       <th id="T_6db0a_level0_col13" class="col_heading level0 col13" >SWALLOWING DIFFICULTY</th>
#       <th id="T_6db0a_level0_col14" class="col_heading level0 col14" >CHEST PAIN</th>
#       <th id="T_6db0a_level0_col15" class="col_heading level0 col15" >LUNG_CANCER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6db0a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6db0a_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_6db0a_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_6db0a_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_6db0a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_6db0a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_6db0a_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_6db0a_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_6db0a_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_6db0a_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_6db0a_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_6db0a_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_6db0a_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_6db0a_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_6db0a_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_6db0a_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_6db0a_row0_col15" class="data row0 col15" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Như vậy, không còn bản ghi nào còn thiếu cả

# %%
dup = data[data.duplicated()].shape[0]
print(f"Có tổng cộng {dup} bản ghi bị trùng lặp trên tổng số {data.shape[0]} bản ghi trong tập dữ liệu.")
# Out:
# Có tổng cộng 33 bản ghi bị trùng lặp trên tổng số 309 bản ghi trong tập dữ liệu.

# %%
data.drop_duplicates(keep='first',inplace=True)
print(f"\nSau khi loại bỏ các bản ghi bị trùng lặp chúng ta còn {data.shape[0]} bản ghi trong tập dữ liệu.")
# Out:
# Sau khi loại bỏ các bản ghi bị trùng lặp chúng ta còn 276 bản ghi trong tập dữ liệu.

# %% [markdown]
# <a id="5"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Số hóa các thuộc tính trong tập dữ liệu</p>

# %% [markdown]
# Chúng ta thay thế tất cả các **giá trị số** thành **giá trị phân loại** để việc trực quan hóa trở nên tốt hơn và hiệu quả hơn. Tất cả các giá trị **2** và **1** sẽ được thay thế tương ứng bằng **"YES"** và **"NO"**. Đồng thời, thay thế **"M"** và **"F"** lần lượt bằng **"Male"** và **"Female"** trong cột **"GENDER"**.

# %%
data_temp = data.copy()
data_temp["GENDER"] = data_temp["GENDER"].replace({"M" : "Male" , "F" : "Female"})

for column in data_temp.columns:
    data_temp[column] = data_temp[column].replace({2: "Yes" , 1 : "No"})

data_temp.head().style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_199fa_row0_col0, #T_199fa_row0_col1, #T_199fa_row0_col2, #T_199fa_row0_col3, #T_199fa_row0_col4, #T_199fa_row0_col5, #T_199fa_row0_col6, #T_199fa_row0_col7, #T_199fa_row0_col8, #T_199fa_row0_col9, #T_199fa_row0_col10, #T_199fa_row0_col11, #T_199fa_row0_col12, #T_199fa_row0_col13, #T_199fa_row0_col14, #T_199fa_row0_col15, #T_199fa_row1_col0, #T_199fa_row1_col1, #T_199fa_row1_col2, #T_199fa_row1_col3, #T_199fa_row1_col4, #T_199fa_row1_col5, #T_199fa_row1_col6, #T_199fa_row1_col7, #T_199fa_row1_col8, #T_199fa_row1_col9, #T_199fa_row1_col10, #T_199fa_row1_col11, #T_199fa_row1_col12, #T_199fa_row1_col13, #T_199fa_row1_col14, #T_199fa_row1_col15, #T_199fa_row2_col0, #T_199fa_row2_col1, #T_199fa_row2_col2, #T_199fa_row2_col3, #T_199fa_row2_col4, #T_199fa_row2_col5, #T_199fa_row2_col6, #T_199fa_row2_col7, #T_199fa_row2_col8, #T_199fa_row2_col9, #T_199fa_row2_col10, #T_199fa_row2_col11, #T_199fa_row2_col12, #T_199fa_row2_col13, #T_199fa_row2_col14, #T_199fa_row2_col15, #T_199fa_row3_col0, #T_199fa_row3_col1, #T_199fa_row3_col2, #T_199fa_row3_col3, #T_199fa_row3_col4, #T_199fa_row3_col5, #T_199fa_row3_col6, #T_199fa_row3_col7, #T_199fa_row3_col8, #T_199fa_row3_col9, #T_199fa_row3_col10, #T_199fa_row3_col11, #T_199fa_row3_col12, #T_199fa_row3_col13, #T_199fa_row3_col14, #T_199fa_row3_col15, #T_199fa_row4_col0, #T_199fa_row4_col1, #T_199fa_row4_col2, #T_199fa_row4_col3, #T_199fa_row4_col4, #T_199fa_row4_col5, #T_199fa_row4_col6, #T_199fa_row4_col7, #T_199fa_row4_col8, #T_199fa_row4_col9, #T_199fa_row4_col10, #T_199fa_row4_col11, #T_199fa_row4_col12, #T_199fa_row4_col13, #T_199fa_row4_col14, #T_199fa_row4_col15 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_199fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_199fa_level0_col0" class="col_heading level0 col0" >GENDER</th>
#       <th id="T_199fa_level0_col1" class="col_heading level0 col1" >AGE</th>
#       <th id="T_199fa_level0_col2" class="col_heading level0 col2" >SMOKING</th>
#       <th id="T_199fa_level0_col3" class="col_heading level0 col3" >YELLOW_FINGERS</th>
#       <th id="T_199fa_level0_col4" class="col_heading level0 col4" >ANXIETY</th>
#       <th id="T_199fa_level0_col5" class="col_heading level0 col5" >PEER_PRESSURE</th>
#       <th id="T_199fa_level0_col6" class="col_heading level0 col6" >CHRONIC DISEASE</th>
#       <th id="T_199fa_level0_col7" class="col_heading level0 col7" >FATIGUE </th>
#       <th id="T_199fa_level0_col8" class="col_heading level0 col8" >ALLERGY </th>
#       <th id="T_199fa_level0_col9" class="col_heading level0 col9" >WHEEZING</th>
#       <th id="T_199fa_level0_col10" class="col_heading level0 col10" >ALCOHOL CONSUMING</th>
#       <th id="T_199fa_level0_col11" class="col_heading level0 col11" >COUGHING</th>
#       <th id="T_199fa_level0_col12" class="col_heading level0 col12" >SHORTNESS OF BREATH</th>
#       <th id="T_199fa_level0_col13" class="col_heading level0 col13" >SWALLOWING DIFFICULTY</th>
#       <th id="T_199fa_level0_col14" class="col_heading level0 col14" >CHEST PAIN</th>
#       <th id="T_199fa_level0_col15" class="col_heading level0 col15" >LUNG_CANCER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_199fa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_199fa_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_199fa_row0_col1" class="data row0 col1" >69</td>
#       <td id="T_199fa_row0_col2" class="data row0 col2" >No</td>
#       <td id="T_199fa_row0_col3" class="data row0 col3" >Yes</td>
#       <td id="T_199fa_row0_col4" class="data row0 col4" >Yes</td>
#       <td id="T_199fa_row0_col5" class="data row0 col5" >No</td>
#       <td id="T_199fa_row0_col6" class="data row0 col6" >No</td>
#       <td id="T_199fa_row0_col7" class="data row0 col7" >Yes</td>
#       <td id="T_199fa_row0_col8" class="data row0 col8" >No</td>
#       <td id="T_199fa_row0_col9" class="data row0 col9" >Yes</td>
#       <td id="T_199fa_row0_col10" class="data row0 col10" >Yes</td>
#       <td id="T_199fa_row0_col11" class="data row0 col11" >Yes</td>
#       <td id="T_199fa_row0_col12" class="data row0 col12" >Yes</td>
#       <td id="T_199fa_row0_col13" class="data row0 col13" >Yes</td>
#       <td id="T_199fa_row0_col14" class="data row0 col14" >Yes</td>
#       <td id="T_199fa_row0_col15" class="data row0 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_199fa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_199fa_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_199fa_row1_col1" class="data row1 col1" >74</td>
#       <td id="T_199fa_row1_col2" class="data row1 col2" >Yes</td>
#       <td id="T_199fa_row1_col3" class="data row1 col3" >No</td>
#       <td id="T_199fa_row1_col4" class="data row1 col4" >No</td>
#       <td id="T_199fa_row1_col5" class="data row1 col5" >No</td>
#       <td id="T_199fa_row1_col6" class="data row1 col6" >Yes</td>
#       <td id="T_199fa_row1_col7" class="data row1 col7" >Yes</td>
#       <td id="T_199fa_row1_col8" class="data row1 col8" >Yes</td>
#       <td id="T_199fa_row1_col9" class="data row1 col9" >No</td>
#       <td id="T_199fa_row1_col10" class="data row1 col10" >No</td>
#       <td id="T_199fa_row1_col11" class="data row1 col11" >No</td>
#       <td id="T_199fa_row1_col12" class="data row1 col12" >Yes</td>
#       <td id="T_199fa_row1_col13" class="data row1 col13" >Yes</td>
#       <td id="T_199fa_row1_col14" class="data row1 col14" >Yes</td>
#       <td id="T_199fa_row1_col15" class="data row1 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_199fa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_199fa_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_199fa_row2_col1" class="data row2 col1" >59</td>
#       <td id="T_199fa_row2_col2" class="data row2 col2" >No</td>
#       <td id="T_199fa_row2_col3" class="data row2 col3" >No</td>
#       <td id="T_199fa_row2_col4" class="data row2 col4" >No</td>
#       <td id="T_199fa_row2_col5" class="data row2 col5" >Yes</td>
#       <td id="T_199fa_row2_col6" class="data row2 col6" >No</td>
#       <td id="T_199fa_row2_col7" class="data row2 col7" >Yes</td>
#       <td id="T_199fa_row2_col8" class="data row2 col8" >No</td>
#       <td id="T_199fa_row2_col9" class="data row2 col9" >Yes</td>
#       <td id="T_199fa_row2_col10" class="data row2 col10" >No</td>
#       <td id="T_199fa_row2_col11" class="data row2 col11" >Yes</td>
#       <td id="T_199fa_row2_col12" class="data row2 col12" >Yes</td>
#       <td id="T_199fa_row2_col13" class="data row2 col13" >No</td>
#       <td id="T_199fa_row2_col14" class="data row2 col14" >Yes</td>
#       <td id="T_199fa_row2_col15" class="data row2 col15" >NO</td>
#     </tr>
#     <tr>
#       <th id="T_199fa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_199fa_row3_col0" class="data row3 col0" >Male</td>
#       <td id="T_199fa_row3_col1" class="data row3 col1" >63</td>
#       <td id="T_199fa_row3_col2" class="data row3 col2" >Yes</td>
#       <td id="T_199fa_row3_col3" class="data row3 col3" >Yes</td>
#       <td id="T_199fa_row3_col4" class="data row3 col4" >Yes</td>
#       <td id="T_199fa_row3_col5" class="data row3 col5" >No</td>
#       <td id="T_199fa_row3_col6" class="data row3 col6" >No</td>
#       <td id="T_199fa_row3_col7" class="data row3 col7" >No</td>
#       <td id="T_199fa_row3_col8" class="data row3 col8" >No</td>
#       <td id="T_199fa_row3_col9" class="data row3 col9" >No</td>
#       <td id="T_199fa_row3_col10" class="data row3 col10" >Yes</td>
#       <td id="T_199fa_row3_col11" class="data row3 col11" >No</td>
#       <td id="T_199fa_row3_col12" class="data row3 col12" >No</td>
#       <td id="T_199fa_row3_col13" class="data row3 col13" >Yes</td>
#       <td id="T_199fa_row3_col14" class="data row3 col14" >Yes</td>
#       <td id="T_199fa_row3_col15" class="data row3 col15" >NO</td>
#     </tr>
#     <tr>
#       <th id="T_199fa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_199fa_row4_col0" class="data row4 col0" >Female</

# %% [markdown]
# <a id="6"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Trực quan hóa dữ liệu</p>

# %%
sns.set_style("whitegrid")
sns.set_context("poster",font_scale = .7)

palette = ["#1d7874","#679289","#f4c095","#ee2e31","#ffb563","#918450","#f85e00","#a41623","#9a031e","#d6d6d6","#ffee32","#ffd100","#333533","#202020"]

# sns.palplot(sns.color_palette(palette))
# plt.show()

# %%
data_temp_pos = data_temp[data_temp["LUNG_CANCER"] == "YES"]
data_temp_pos.head().style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_e9aec_row0_col0, #T_e9aec_row0_col1, #T_e9aec_row0_col2, #T_e9aec_row0_col3, #T_e9aec_row0_col4, #T_e9aec_row0_col5, #T_e9aec_row0_col6, #T_e9aec_row0_col7, #T_e9aec_row0_col8, #T_e9aec_row0_col9, #T_e9aec_row0_col10, #T_e9aec_row0_col11, #T_e9aec_row0_col12, #T_e9aec_row0_col13, #T_e9aec_row0_col14, #T_e9aec_row0_col15, #T_e9aec_row1_col0, #T_e9aec_row1_col1, #T_e9aec_row1_col2, #T_e9aec_row1_col3, #T_e9aec_row1_col4, #T_e9aec_row1_col5, #T_e9aec_row1_col6, #T_e9aec_row1_col7, #T_e9aec_row1_col8, #T_e9aec_row1_col9, #T_e9aec_row1_col10, #T_e9aec_row1_col11, #T_e9aec_row1_col12, #T_e9aec_row1_col13, #T_e9aec_row1_col14, #T_e9aec_row1_col15, #T_e9aec_row2_col0, #T_e9aec_row2_col1, #T_e9aec_row2_col2, #T_e9aec_row2_col3, #T_e9aec_row2_col4, #T_e9aec_row2_col5, #T_e9aec_row2_col6, #T_e9aec_row2_col7, #T_e9aec_row2_col8, #T_e9aec_row2_col9, #T_e9aec_row2_col10, #T_e9aec_row2_col11, #T_e9aec_row2_col12, #T_e9aec_row2_col13, #T_e9aec_row2_col14, #T_e9aec_row2_col15, #T_e9aec_row3_col0, #T_e9aec_row3_col1, #T_e9aec_row3_col2, #T_e9aec_row3_col3, #T_e9aec_row3_col4, #T_e9aec_row3_col5, #T_e9aec_row3_col6, #T_e9aec_row3_col7, #T_e9aec_row3_col8, #T_e9aec_row3_col9, #T_e9aec_row3_col10, #T_e9aec_row3_col11, #T_e9aec_row3_col12, #T_e9aec_row3_col13, #T_e9aec_row3_col14, #T_e9aec_row3_col15, #T_e9aec_row4_col0, #T_e9aec_row4_col1, #T_e9aec_row4_col2, #T_e9aec_row4_col3, #T_e9aec_row4_col4, #T_e9aec_row4_col5, #T_e9aec_row4_col6, #T_e9aec_row4_col7, #T_e9aec_row4_col8, #T_e9aec_row4_col9, #T_e9aec_row4_col10, #T_e9aec_row4_col11, #T_e9aec_row4_col12, #T_e9aec_row4_col13, #T_e9aec_row4_col14, #T_e9aec_row4_col15 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_e9aec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9aec_level0_col0" class="col_heading level0 col0" >GENDER</th>
#       <th id="T_e9aec_level0_col1" class="col_heading level0 col1" >AGE</th>
#       <th id="T_e9aec_level0_col2" class="col_heading level0 col2" >SMOKING</th>
#       <th id="T_e9aec_level0_col3" class="col_heading level0 col3" >YELLOW_FINGERS</th>
#       <th id="T_e9aec_level0_col4" class="col_heading level0 col4" >ANXIETY</th>
#       <th id="T_e9aec_level0_col5" class="col_heading level0 col5" >PEER_PRESSURE</th>
#       <th id="T_e9aec_level0_col6" class="col_heading level0 col6" >CHRONIC DISEASE</th>
#       <th id="T_e9aec_level0_col7" class="col_heading level0 col7" >FATIGUE </th>
#       <th id="T_e9aec_level0_col8" class="col_heading level0 col8" >ALLERGY </th>
#       <th id="T_e9aec_level0_col9" class="col_heading level0 col9" >WHEEZING</th>
#       <th id="T_e9aec_level0_col10" class="col_heading level0 col10" >ALCOHOL CONSUMING</th>
#       <th id="T_e9aec_level0_col11" class="col_heading level0 col11" >COUGHING</th>
#       <th id="T_e9aec_level0_col12" class="col_heading level0 col12" >SHORTNESS OF BREATH</th>
#       <th id="T_e9aec_level0_col13" class="col_heading level0 col13" >SWALLOWING DIFFICULTY</th>
#       <th id="T_e9aec_level0_col14" class="col_heading level0 col14" >CHEST PAIN</th>
#       <th id="T_e9aec_level0_col15" class="col_heading level0 col15" >LUNG_CANCER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9aec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e9aec_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_e9aec_row0_col1" class="data row0 col1" >69</td>
#       <td id="T_e9aec_row0_col2" class="data row0 col2" >No</td>
#       <td id="T_e9aec_row0_col3" class="data row0 col3" >Yes</td>
#       <td id="T_e9aec_row0_col4" class="data row0 col4" >Yes</td>
#       <td id="T_e9aec_row0_col5" class="data row0 col5" >No</td>
#       <td id="T_e9aec_row0_col6" class="data row0 col6" >No</td>
#       <td id="T_e9aec_row0_col7" class="data row0 col7" >Yes</td>
#       <td id="T_e9aec_row0_col8" class="data row0 col8" >No</td>
#       <td id="T_e9aec_row0_col9" class="data row0 col9" >Yes</td>
#       <td id="T_e9aec_row0_col10" class="data row0 col10" >Yes</td>
#       <td id="T_e9aec_row0_col11" class="data row0 col11" >Yes</td>
#       <td id="T_e9aec_row0_col12" class="data row0 col12" >Yes</td>
#       <td id="T_e9aec_row0_col13" class="data row0 col13" >Yes</td>
#       <td id="T_e9aec_row0_col14" class="data row0 col14" >Yes</td>
#       <td id="T_e9aec_row0_col15" class="data row0 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_e9aec_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e9aec_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_e9aec_row1_col1" class="data row1 col1" >74</td>
#       <td id="T_e9aec_row1_col2" class="data row1 col2" >Yes</td>
#       <td id="T_e9aec_row1_col3" class="data row1 col3" >No</td>
#       <td id="T_e9aec_row1_col4" class="data row1 col4" >No</td>
#       <td id="T_e9aec_row1_col5" class="data row1 col5" >No</td>
#       <td id="T_e9aec_row1_col6" class="data row1 col6" >Yes</td>
#       <td id="T_e9aec_row1_col7" class="data row1 col7" >Yes</td>
#       <td id="T_e9aec_row1_col8" class="data row1 col8" >Yes</td>
#       <td id="T_e9aec_row1_col9" class="data row1 col9" >No</td>
#       <td id="T_e9aec_row1_col10" class="data row1 col10" >No</td>
#       <td id="T_e9aec_row1_col11" class="data row1 col11" >No</td>
#       <td id="T_e9aec_row1_col12" class="data row1 col12" >Yes</td>
#       <td id="T_e9aec_row1_col13" class="data row1 col13" >Yes</td>
#       <td id="T_e9aec_row1_col14" class="data row1 col14" >Yes</td>
#       <td id="T_e9aec_row1_col15" class="data row1 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_e9aec_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_e9aec_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_e9aec_row2_col1" class="data row2 col1" >75</td>
#       <td id="T_e9aec_row2_col2" class="data row2 col2" >No</td>
#       <td id="T_e9aec_row2_col3" class="data row2 col3" >Yes</td>
#       <td id="T_e9aec_row2_col4" class="data row2 col4" >No</td>
#       <td id="T_e9aec_row2_col5" class="data row2 col5" >No</td>
#       <td id="T_e9aec_row2_col6" class="data row2 col6" >Yes</td>
#       <td id="T_e9aec_row2_col7" class="data row2 col7" >Yes</td>
#       <td id="T_e9aec_row2_col8" class="data row2 col8" >Yes</td>
#       <td id="T_e9aec_row2_col9" class="data row2 col9" >Yes</td>
#       <td id="T_e9aec_row2_col10" class="data row2 col10" >No</td>
#       <td id="T_e9aec_row2_col11" class="data row2 col11" >Yes</td>
#       <td id="T_e9aec_row2_col12" class="data row2 col12" >Yes</td>
#       <td id="T_e9aec_row2_col13" class="data row2 col13" >No</td>
#       <td id="T_e9aec_row2_col14" class="data row2 col14" >No</td>
#       <td id="T_e9aec_row2_col15" class="data row2 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_e9aec_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_e9aec_row3_col0" class="data row3 col0" >Male</td>
#       <td id="T_e9aec_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_e9aec_row3_col2" class="data row3 col2" >Yes</td>
#       <td id="T_e9aec_row3_col3" class="data row3 col3" >No</td>
#       <td id="T_e9aec_row3_col4" class="data row3 col4" >No</td>
#       <td id="T_e9aec_row3_col5" class="data row3 col5" >No</td>
#       <td id="T_e9aec_row3_col6" class="data row3 col6" >No</td>
#       <td id="T_e9aec_row3_col7" class="data row3 col7" >Yes</td>
#       <td id="T_e9aec_row3_col8" class="data row3 col8" >No</td>
#       <td id="T_e9aec_row3_col9" class="data row3 col9" >Yes</td>
#       <td id="T_e9aec_row3_col10" class="data row3 col10" >Yes</td>
#       <td id="T_e9aec_row3_col11" class="data row3 col11" >Yes</td>
#       <td id="T_e9aec_row3_col12" class="data row3 col12" >Yes</td>
#       <td id="T_e9aec_row3_col13" class="data row3 col13" >No</td>
#       <td id="T_e9aec_row3_col14" class="data row3 col14" >Yes</td>
#       <td id="T_e9aec_row3_col15" class="data row3 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_e9aec_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_e9aec_row4_col0" class="data row4 col0" >Fema

# %%
import warnings
warnings.filterwarnings("ignore")
_, axs = plt.subplots(2,1,figsize=(20,10),sharex=True,sharey=True)
plt.tight_layout(pad=4.0)

sns.histplot(data_temp_pos[data_temp_pos["GENDER"]=="Male"]["AGE"],color=palette[11],kde=True,ax=axs[0],bins=20,alpha=1,fill=True)
axs[0].lines[0].set_color(palette[12])
axs[0].set_title("\nBiểu đồ phân bổ độ tuổi của nam giới mắc ung thư phổi\n",fontsize=20)
axs[0].set_xlabel("Age")
axs[0].set_ylabel("Quantity")

sns.histplot(data_temp_pos[data_temp_pos["GENDER"]=="Female"]["AGE"],color=palette[12],kde=True,ax=axs[1],bins=20,alpha=1,fill=True)
axs[1].lines[0].set_color(palette[11])
axs[1].set_title("\nBiểu đồ phân bộ độ tuổi của nữ giới mắc ung thư phổi\n",fontsize=20)
axs[1].set_xlabel("Age")
axs[1].set_ylabel("Quantity")

sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# **Let's stack them together in a same figure.**

# %%
plt.subplots(figsize=(20, 8))
p = sns.histplot(data=data_temp_pos,x="AGE",hue="GENDER",multiple="stack",palette=palette[11:13],kde=True,shrink=.99,bins=20,alpha=1,fill=True)
p.axes.lines[0].set_color(palette[11])
p.axes.lines[1].set_color(palette[12])
p.axes.set_title("\nBiểu đồ phân bổ độ tuổi bị ung thư phổi ở cả nam và nữ giới\n",fontsize=20)
plt.ylabel("Count")
plt.xlabel("Age")

sns.despine(left=True, bottom=True)
plt.show()

# %%
plt.subplots(figsize=(12, 12))

labels = "Male","Female"
size = 0.5

wedges, texts, autotexts = plt.pie([len(data_temp_pos[data_temp_pos["GENDER"]=="Male"]["GENDER"]),
                                    len(data_temp_pos[data_temp_pos["GENDER"]=="Female"]["GENDER"])],
                                    explode = (0,0),
                                    textprops=dict(size= 25, color= "white"),
                                    autopct="%.2f%%", 
                                    pctdistance = 0.7,
                                    radius=.9, 
                                    colors = ["#0f4c5c","#FFC300"], 
                                    shadow = True,
                                    wedgeprops=dict(width = size, edgecolor = "white", 
                                    linewidth = 5),
                                    startangle = 0)

plt.legend(wedges, labels, title="Category",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))
plt.title("\nBiểu đồ tròn",fontsize=20)
plt.show()

# %% [markdown]
# <a id="10"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Phân bổ số lượng bệnh nhân có thói quen uống rượu và hút thuốc lá</p>

# %%
_, axs = plt.subplots(1,2,figsize=(20,8),sharex=True,sharey=True)
plt.tight_layout(pad=4.0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="SMOKING",hue_order=["Yes","No"],ax=axs[0],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0].set_title("\nPhân bổ số lượng bệnh nhân hút thuộc lá\n",fontsize=20)
axs[0].set_xlabel("Gender")
axs[0].set_ylabel("Quantity")
for container in axs[0].containers:
    axs[0].bar_label(container,label_type="center",padding=2,size=25,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="ALCOHOL CONSUMING",hue_order=["Yes","No"],ax=axs[1],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1].set_title("\nPhân bổ bệnh nhân uống rượu\n",fontsize=20)
axs[1].set_xlabel("Gender")
axs[1].set_ylabel("Quantity")
for container in axs[1].containers:
    axs[1].bar_label(container,label_type="center",padding=2,size=25,color="white",rotation=0)

sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# <a id="11"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Phân bổ triệu chứng các ca bệnh theo giới tính</p>

# %%
_, axs = plt.subplots(2,5,figsize=(20,14),sharex=False,sharey=True)
plt.tight_layout(pad=4.0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="YELLOW_FINGERS",hue_order=["Yes","No"],ax=axs[0,0],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,0].set_ylabel("Total")
axs[0,0].legend(title="Yellow Fingers",loc="upper right")
for container in axs[0,0].containers:
    axs[0,0].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="ANXIETY",hue_order=["Yes","No"],ax=axs[0,1],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,1].set_ylabel("Total")
axs[0,1].legend(title="Anxiety",loc="upper right")
for container in axs[0,1].containers:
    axs[0,1].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="CHRONIC DISEASE",hue_order=["Yes","No"],ax=axs[0,2],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,2].set_ylabel("Total")
axs[0,2].legend(title="Chronic Disease",loc="upper right")
for container in axs[0,2].containers:
    axs[0,2].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="CHEST PAIN",hue_order=["Yes","No"],ax=axs[0,3],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,3].set_ylabel("Total")
axs[0,3].legend(title="Chest Pain",loc="upper right")
for container in axs[0,3].containers:
    axs[0,3].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="FATIGUE ",hue_order=["Yes","No"],ax=axs[0,4],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,4].set_ylabel("Total")
axs[0,4].legend(title="Fatigue",loc="upper right")
for container in axs[0,4].containers:
    axs[0,4].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="WHEEZING",hue_order=["Yes","No"],ax=axs[1,0],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,0].set_ylabel("Total")
axs[1,0].legend(title="Wheezing",loc="upper right")
for container in axs[1,0].containers:
    axs[1,0].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="COUGHING",hue_order=["Yes","No"],ax=axs[1,1],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,1].set_ylabel("Total")
axs[1,1].legend(title="Coughing",loc="upper right")
for container in axs[1,1].containers:
    axs[1,1].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="SHORTNESS OF BREATH",hue_order=["Yes","No"],ax=axs[1,2],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,2].set_ylabel("Total")
axs[1,2].legend(title="Short Breath",loc="upper right")
for container in axs[1,2].containers:
    axs[1,2].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="SWALLOWING DIFFICULTY",hue_order=["Yes","No"],ax=axs[1,3],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,3].set_ylabel("Total")
axs[1,3].legend(title="Swallowing Difficulty",loc="upper right")
for container in axs[1,3].containers:
    axs[1,3].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)    

sns.countplot(data=data_temp_pos,x="GENDER",hue="ALLERGY ",hue_order=["Yes","No"],ax=axs[1,4],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,4].set_ylabel("Total")
axs[1,4].legend(title="Allergy",loc="upper right")
for container in axs[1,4].containers:
    axs[1,4].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)    

sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# Let's convert the target feature **"LUNG_CANCER"** from **Categorical** to **Numerical** data type by using **Label Encoder**. And converting the **"GENDER"** column from **Categorical** to **Numerical** data type by using **"One Hot Encoder"** for avoiding unexpected gender bias.

# %%
from sklearn.preprocessing import LabelEncoder
LabelEncoder = LabelEncoder()

data["GENDER"] = data["GENDER"].replace({"M" : "Male" , "F" : "Female"})
data["LUNG_CANCER"] = LabelEncoder.fit_transform(data["LUNG_CANCER"])

data = pd.get_dummies(data, columns= ["GENDER"])
data.rename(columns={"GENDER_Male" : "MALE", "GENDER_Female" : "FEMALE", "YELLOW_FINGERS" : "YELLOW FINGERS", "PEER_PRESSURE" : "PEER PRESSURE", "LUNG_CANCER" : "LUNG CANCER", "FATIGUE " : "FATIGUE", "ALLERGY " : "ALLERGY"}, inplace=True)
data = data[["AGE","MALE","FEMALE","ALCOHOL CONSUMING","CHEST PAIN","SHORTNESS OF BREATH","COUGHING","PEER PRESSURE","CHRONIC DISEASE","SWALLOWING DIFFICULTY","YELLOW FINGERS","ANXIETY","FATIGUE","ALLERGY","WHEEZING","LUNG CANCER"]]
data.head().style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_3c17c_row0_col0, #T_3c17c_row0_col1, #T_3c17c_row0_col2, #T_3c17c_row0_col3, #T_3c17c_row0_col4, #T_3c17c_row0_col5, #T_3c17c_row0_col6, #T_3c17c_row0_col7, #T_3c17c_row0_col8, #T_3c17c_row0_col9, #T_3c17c_row0_col10, #T_3c17c_row0_col11, #T_3c17c_row0_col12, #T_3c17c_row0_col13, #T_3c17c_row0_col14, #T_3c17c_row0_col15, #T_3c17c_row1_col0, #T_3c17c_row1_col1, #T_3c17c_row1_col2, #T_3c17c_row1_col3, #T_3c17c_row1_col4, #T_3c17c_row1_col5, #T_3c17c_row1_col6, #T_3c17c_row1_col7, #T_3c17c_row1_col8, #T_3c17c_row1_col9, #T_3c17c_row1_col10, #T_3c17c_row1_col11, #T_3c17c_row1_col12, #T_3c17c_row1_col13, #T_3c17c_row1_col14, #T_3c17c_row1_col15, #T_3c17c_row2_col0, #T_3c17c_row2_col1, #T_3c17c_row2_col2, #T_3c17c_row2_col3, #T_3c17c_row2_col4, #T_3c17c_row2_col5, #T_3c17c_row2_col6, #T_3c17c_row2_col7, #T_3c17c_row2_col8, #T_3c17c_row2_col9, #T_3c17c_row2_col10, #T_3c17c_row2_col11, #T_3c17c_row2_col12, #T_3c17c_row2_col13, #T_3c17c_row2_col14, #T_3c17c_row2_col15, #T_3c17c_row3_col0, #T_3c17c_row3_col1, #T_3c17c_row3_col2, #T_3c17c_row3_col3, #T_3c17c_row3_col4, #T_3c17c_row3_col5, #T_3c17c_row3_col6, #T_3c17c_row3_col7, #T_3c17c_row3_col8, #T_3c17c_row3_col9, #T_3c17c_row3_col10, #T_3c17c_row3_col11, #T_3c17c_row3_col12, #T_3c17c_row3_col13, #T_3c17c_row3_col14, #T_3c17c_row3_col15, #T_3c17c_row4_col0, #T_3c17c_row4_col1, #T_3c17c_row4_col2, #T_3c17c_row4_col3, #T_3c17c_row4_col4, #T_3c17c_row4_col5, #T_3c17c_row4_col6, #T_3c17c_row4_col7, #T_3c17c_row4_col8, #T_3c17c_row4_col9, #T_3c17c_row4_col10, #T_3c17c_row4_col11, #T_3c17c_row4_col12, #T_3c17c_row4_col13, #T_3c17c_row4_col14, #T_3c17c_row4_col15 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_3c17c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c17c_level0_col0" class="col_heading level0 col0" >AGE</th>
#       <th id="T_3c17c_level0_col1" class="col_heading level0 col1" >MALE</th>
#       <th id="T_3c17c_level0_col2" class="col_heading level0 col2" >FEMALE</th>
#       <th id="T_3c17c_level0_col3" class="col_heading level0 col3" >ALCOHOL CONSUMING</th>
#       <th id="T_3c17c_level0_col4" class="col_heading level0 col4" >CHEST PAIN</th>
#       <th id="T_3c17c_level0_col5" class="col_heading level0 col5" >SHORTNESS OF BREATH</th>
#       <th id="T_3c17c_level0_col6" class="col_heading level0 col6" >COUGHING</th>
#       <th id="T_3c17c_level0_col7" class="col_heading level0 col7" >PEER PRESSURE</th>
#       <th id="T_3c17c_level0_col8" class="col_heading level0 col8" >CHRONIC DISEASE</th>
#       <th id="T_3c17c_level0_col9" class="col_heading level0 col9" >SWALLOWING DIFFICULTY</th>
#       <th id="T_3c17c_level0_col10" class="col_heading level0 col10" >YELLOW FINGERS</th>
#       <th id="T_3c17c_level0_col11" class="col_heading level0 col11" >ANXIETY</th>
#       <th id="T_3c17c_level0_col12" class="col_heading level0 col12" >FATIGUE</th>
#       <th id="T_3c17c_level0_col13" class="col_heading level0 col13" >ALLERGY</th>
#       <th id="T_3c17c_level0_col14" class="col_heading level0 col14" >WHEEZING</th>
#       <th id="T_3c17c_level0_col15" class="col_heading level0 col15" >LUNG CANCER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c17c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3c17c_row0_col0" class="data row0 col0" >69</td>
#       <td id="T_3c17c_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_3c17c_row0_col2" class="data row0 col2" >False</td>
#       <td id="T_3c17c_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_3c17c_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_3c17c_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_3c17c_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_3c17c_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_3c17c_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_3c17c_row0_col9" class="data row0 col9" >2</td>
#       <td id="T_3c17c_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_3c17c_row0_col11" class="data row0 col11" >2</td>
#       <td id="T_3c17c_row0_col12" class="data row0 col12" >2</td>
#       <td id="T_3c17c_row0_col13" class="data row0 col13" >1</td>
#       <td id="T_3c17c_row0_col14" class="data row0 col14" >2</td>
#       <td id="T_3c17c_row0_col15" class="data row0 col15" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3c17c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3c17c_row1_col0" class="data row1 col0" >74</td>
#       <td id="T_3c17c_row1_col1" class="data row1 col1" >True</td>
#       <td id="T_3c17c_row1_col2" class="data row1 col2" >False</td>
#       <td id="T_3c17c_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_3c17c_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_3c17c_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_3c17c_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_3c17c_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_3c17c_row1_col8" class="data row1 col8" >2</td>
#       <td id="T_3c17c_row1_col9" class="data row1 col9" >2</td>
#       <td id="T_3c17c_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_3c17c_row1_col11" class="data row1 col11" >1</td>
#       <td id="T_3c17c_row1_col12" class="data row1 col12" >2</td>
#       <td id="T_3c17c_row1_col13" class="data row1 col13" >2</td>
#       <td id="T_3c17c_row1_col14" class="data row1 col14" >1</td>
#       <td id="T_3c17c_row1_col15" class="data row1 col15" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3c17c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3c17c_row2_col0" class="data row2 col0" >59</td>
#       <td id="T_3c17c_row2_col1" class="data row2 col1" >False</td>
#       <td id="T_3c17c_row2_col2" class="data row2 col2" >True</td>
#       <td id="T_3c17c_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_3c17c_row2_col4" class="data row2 col4" >2</td>
#       <td id="T_3c17c_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_3c17c_row2_col6" class="data row2 col6" >2</td>
#       <td id="T_3c17c_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_3c17c_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_3c17c_row2_col9" class="data row2 col9" >1</td>
#       <td id="T_3c17c_row2_col10" class="data row2 col10" >1</td>
#       <td id="T_3c17c_row2_col11" class="data row2 col11" >1</td>
#       <td id="T_3c17c_row2_col12" class="data row2 col12" >2</td>
#       <td id="T_3c17c_row2_col13" class="data row2 col13" >1</td>
#       <td id="T_3c17c_row2_col14" class="data row2 col14" >2</td>
#       <td id="T_3c17c_row2_col15" class="data row2 col15" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3c17c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3c17c_row3_col0" class="data row3 col0" >63</td>
#       <td id="T_3c17c_row3_col1" class="data row3 col1" >True</td>
#       <td id="T_3c17c_row3_col2" class="data row3 col2" >False</td>
#       <td id="T_3c17c_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_3c17c_row3_col4" class="data row3 col4" >2</td>
#       <td id="T_3c17c_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_3c17c_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_3c17c_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_3c17c_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_3c17c_row3_col9" class="data row3 col9" >2</td>
#       <td id="T_3c17c_row3_col10" class="data row3 col10" >2</td>
#       <td id="T_3c17c_row3_col11" class="data row3 col11" >2</td>
#       <td id="T_3c17c_row3_col12" class="data row3 col12" >1</td>
#       <td id="T_3c17c_row3_col13" class="data row3 col13" >1</td>
#       <td id="T_3c17c_row3_col14" class="data row3 col14" >1</td>
#       <td id="T_3c17c_row3_col15" class="data row3 col15" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3c17c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3c17c_row4_col0" class="data row4 col0" >63</td>
#       <td id="T_3c17c_row4_col1" class="data row4 col1" >False</td>
#       <td

# %%
plt.subplots(figsize =(16, 12))

p=sns.heatmap(data.corr(), cmap = palette, square=True, cbar_kws=dict(shrink =.99), 
            annot=True, vmin=-1, vmax=1, linewidths=0.1,linecolor='white',annot_kws=dict(fontsize =12))
p.axes.set_title("Hệ số tương quan của các đặc trưng\n", fontsize=25)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <a id="13"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Chia tập dữ liệu Train - Test</p>

# %%
x = data.drop("LUNG CANCER", axis = 1)
y = data["LUNG CANCER"]

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
x = scaler.fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

print(f"Shape of training data : {x_train.shape}, {y_train.shape}")
print(f"Shape of testing data : {x_test.shape}, {y_test.shape}")
# Out:
# Shape of training data : (220, 15), (220,)
# Shape of testing data : (56, 15), (56,)

# %% [markdown]
# <a id="14"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Logistic Regression Model</p>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report


lr = LogisticRegression()
lr.fit(x_train, y_train)
lr_pred = lr.predict(x_test)
lr_conf = confusion_matrix(y_test, lr_pred)
lr_report = classification_report(y_test, lr_pred)
lr_acc = round(accuracy_score(y_test, lr_pred)*100, ndigits = 2)
print(f"\nClassification Report : \n\n{lr_report}")
print(f"\nĐộ chính xác của mô hình Logistic Regression là {lr_acc} %")

# Trực quan hóa confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(lr_conf, annot=True, fmt='d', cmap='YlGnBu', 
            cbar=True, square=True, 
            xticklabels=[0, 1], yticklabels=[0, 1], 
            annot_kws={"size": 16, "weight": "bold", "color": "black"}) 

# Đặt tiêu đề và nhãn trục
plt.title('Confusion Matrix - Lung Cancer (Linear Regression)', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Predicted Label', fontsize=12)
plt.ylabel('True Label', fontsize=12)

# Hiển thị biểu đồ
plt.show()
# Out:
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.42      0.59        12
#            1       0.86      1.00      0.93        44
#
#     accuracy                           0.88        56
#    macro avg       0.93      0.71      0.76        56
# weighted avg       0.89      0.88      0.85        56
#
#
# Độ chính xác của mô hình Logistic Regression là 87.5 %

# %% [markdown]
# <a id="15"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Gaussian Naive Bayes Model</p>

# %%
from sklearn.naive_bayes import GaussianNB

# Khởi tạo và huấn luyện mô hình Gaussian Naive Bayes
gnb = GaussianNB()
gnb.fit(x_train, y_train)

# Dự đoán kết quả và tính toán confusion matrix
gnb_pred = gnb.predict(x_test)
gnb_conf = confusion_matrix(y_test, gnb_pred)
gnb_report = classification_report(y_test, gnb_pred)
gnb_acc = round(accuracy_score(y_test, gnb_pred)*100, ndigits = 2)

# In kết quả báo cáo và độ chính xác
print(f"Confusion Matrix : \n\n{gnb_conf}")
print(f"\nClassification Report : \n\n{gnb_report}")
print(f"\nĐộ chính xác của mô hình Gaussian Naive Bayes là {gnb_acc} %")

# Trực quan hóa confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(gnb_conf, annot=True, fmt='d', cmap='YlGnBu', 
            cbar=True, square=True, 
            xticklabels=[0, 1], yticklabels=[0, 1], 
            annot_kws={"size": 16, "weight": "bold", "color": "black"}) 

# Đặt tiêu đề và nhãn trục
plt.title('Confusion Matrix - Gaussian Naive Bayes', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Predicted Label', fontsize=12)
plt.ylabel('True Label', fontsize=12)

# Hiển thị biểu đồ
plt.show()
# Out:
# Confusion Matrix :
#
# [[ 8  4]
#  [ 1 43]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.67      0.76        12
#            1       0.91      0.98      0.95        44
#
#     accuracy                           0.91        56
#    macro avg       0.90      0.82      0.85        56
# weighted avg       0.91      0.91      0.91        56
#
#
# Độ chính xác của mô hình Gaussian Naive Bayes là 91.07 %

# %% [markdown]
# <a id="17"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Support Vector Machine Model</p>

# %%
from sklearn.svm import SVC

# Khởi tạo và huấn luyện mô hình Support Vector Machine (SVM)
svm = SVC(C=100, gamma=0.002)
svm.fit(x_train, y_train)

# Dự đoán kết quả và tính toán confusion matrix
svm_pred = svm.predict(x_test)
svm_conf = confusion_matrix(y_test, svm_pred)
svm_report = classification_report(y_test, svm_pred)
svm_acc = round(accuracy_score(y_test, svm_pred)*100, ndigits = 2)

# In kết quả báo cáo và độ chính xác
print(f"Confusion Matrix : \n\n{svm_conf}")
print(f"\nClassification Report : \n\n{svm_report}")
print(f"\nĐộ chính xác của mô hình Support Vector Machine là {svm_acc} %")

# Trực quan hóa confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(svm_conf, annot=True, fmt='d', cmap='YlGnBu', 
            cbar=True, square=True, 
            xticklabels=[0, 1], yticklabels=[0, 1], 
            annot_kws={"size": 16, "weight": "bold", "color": "black"}) 

# Đặt tiêu đề và nhãn trục
plt.title('Confusion Matrix - Support Vector Machine', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Predicted Label', fontsize=12)
plt.ylabel('True Label', fontsize=12)

# Hiển thị biểu đồ
plt.show()
# Out:
# Confusion Matrix :
#
# [[ 4  8]
#  [ 0 44]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50        12
#            1       0.85      1.00      0.92        44
#
#     accuracy                           0.86        56
#    macro avg       0.92      0.67      0.71        56
# weighted avg       0.88      0.86      0.83        56
#
#
# Độ chính xác của mô hình Support Vector Machine là 85.71 %

# %% [markdown]
# <a id="18"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Random Forest Model</p>

# %%
from sklearn.ensemble import RandomForestClassifier


# Khởi tạo và huấn luyện mô hình Random Forest Classifier
rfg = RandomForestClassifier(n_estimators=100, random_state=42)
rfg.fit(x_train, y_train)

# Dự đoán kết quả và tính toán confusion matrix
rfg_pred = rfg.predict(x_test)
rfg_conf = confusion_matrix(y_test, rfg_pred)
rfg_report = classification_report(y_test, rfg_pred)
rfg_acc = round(accuracy_score(y_test, rfg_pred)*100, ndigits = 2)

# In kết quả báo cáo và độ chính xác
print(f"Confusion Matrix : \n\n{rfg_conf}")
print(f"\nClassification Report : \n\n{rfg_report}")
print(f"\nĐộ chính xác của mô hình Random Forest Classifier là {rfg_acc} %")

# Trực quan hóa confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(rfg_conf, annot=True, fmt='d', cmap='YlGnBu', 
            cbar=True, square=True, 
            xticklabels=[0, 1], yticklabels=[0, 1], 
            annot_kws={"size": 16, "weight": "bold", "color": "black"}) 

# Đặt tiêu đề và nhãn trục
plt.title('Confusion Matrix - Random Forest Classifier', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Predicted Label', fontsize=12)
plt.ylabel('True Label', fontsize=12)

# Hiển thị biểu đồ
plt.show()
# Out:
# Confusion Matrix :
#
# [[ 4  8]
#  [ 0 44]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50        12
#            1       0.85      1.00      0.92        44
#
#     accuracy                           0.86        56
#    macro avg       0.92      0.67      0.71        56
# weighted avg       0.88      0.86      0.83        56
#
#
# Độ chính xác của mô hình Random Forest Classifier là 85.71 %

# %% [markdown]
# <a id="19"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">K Nearest Neighbors Model</p>

# %%
from sklearn.neighbors import KNeighborsClassifier

# Khởi tạo và huấn luyện mô hình K-Nearest Neighbors (KNN)
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(x_train, y_train)

# Dự đoán kết quả và tính toán confusion matrix
knn_pred = knn.predict(x_test)
knn_conf = confusion_matrix(y_test, knn_pred)
knn_report = classification_report(y_test, knn_pred)
knn_acc = round(accuracy_score(y_test, knn_pred)*100, ndigits = 2)

# In kết quả báo cáo và độ chính xác
print(f"Confusion Matrix : \n\n{knn_conf}")
print(f"\nClassification Report : \n\n{knn_report}")
print(f"\nĐộ chính xác của mô hình K-Nearest Neighbors Classifier là {knn_acc} %")

# Trực quan hóa confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(knn_conf, annot=True, fmt='d', cmap='YlGnBu', 
            cbar=True, square=True, 
            xticklabels=[0, 1], yticklabels=[0, 1], 
            annot_kws={"size": 16, "weight": "bold", "color": "black"}) 

# Đặt tiêu đề và nhãn trục
plt.title('Confusion Matrix - K Nearest Neighbors', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Predicted Label', fontsize=12)
plt.ylabel('True Label', fontsize=12)

# Hiển thị biểu đồ
plt.show()
# Out:
# Confusion Matrix :
#
# [[ 9  3]
#  [ 1 43]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.75      0.82        12
#            1       0.93      0.98      0.96        44
#
#     accuracy                           0.93        56
#    macro avg       0.92      0.86      0.89        56
# weighted avg       0.93      0.93      0.93        56
#
#
# Độ chính xác của mô hình K-Nearest Neighbors Classifier là 92.86 %

# %% [markdown]
# <a id="20"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Extreme Gradient Boosting Model</p>

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\ledoa\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: numpy in c:\users\ledoa\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\ledoa\anaconda3\lib\site-packages (from xgboost) (1.13.1)

# %%
from xgboost import XGBClassifier

# Khởi tạo và huấn luyện mô hình XGBoost
xgb = XGBClassifier(use_label_encoder=False)
xgb.fit(x_train, y_train)

# Dự đoán kết quả và tính toán confusion matrix
xgb_pred = xgb.predict(x_test)
xgb_conf = confusion_matrix(y_test, xgb_pred)
xgb_report = classification_report(y_test, xgb_pred)
xgb_acc = round(accuracy_score(y_test, xgb_pred)*100, ndigits = 2)

# In kết quả báo cáo và độ chính xác
print(f"Confusion Matrix : \n\n{xgb_conf}")
print(f"\nClassification Report : \n\n{xgb_report}")
print(f"\nĐộ chính xác của mô hình Extreme Gradient Boosting Classifier là {xgb_acc} %")

# Trực quan hóa confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(xgb_conf, annot=True, fmt='d', cmap='YlGnBu', 
            cbar=True, square=True, 
            xticklabels=[0, 1], yticklabels=[0, 1], 
            annot_kws={"size": 16, "weight": "bold", "color": "black"}) 

# Đặt tiêu đề và nhãn trục
plt.title('Confusion Matrix - Extreme Gradient Boosting', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Predicted Label', fontsize=12)
plt.ylabel('True Label', fontsize=12)

# Hiển thị biểu đồ
plt.show()
# Out:
# Confusion Matrix :
#
# [[ 5  7]
#  [ 1 43]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.42      0.56        12
#            1       0.86      0.98      0.91        44
#
#     accuracy                           0.86        56
#    macro avg       0.85      0.70      0.74        56
# weighted avg       0.85      0.86      0.84        56
#
#
# Độ chính xác của mô hình Extreme Gradient Boosting Classifier là 85.71 %

# %% [markdown]
# **Như vậy, mô hình K-Neighbor Nearest đạt kết quả tốt nhất với độ chính xác là 92.86% trên tập dữ liệu kiểm thứ**

# %% [markdown]
# <a id="20"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Lưu mô hình</p>

# %%
import joblib
# Lưu mô hình KNN đã huấn luyện
joblib.dump(knn, 'Model/knn_model.pkl')
joblib.dump(scaler, "Model/scaler.pkl")  
print("Đã lưu mô hình KNN thành công vào file 'knn_model.pkl'")
# Out:
# Đã lưu mô hình KNN thành công vào file 'knn_model.pkl'
